# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("customer.xlsx",usecols="A:AU")
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df.head()
# Out:
#    Gender How old are you?            city  Pin Code  \
# 0    Male       31-40 years          Delhi    110009
# 1  Female       21-30 years          Delhi    110030
# 2  Female       21-30 years  Greater Noida    201308
# 3    Male       21-30 years        Karnal     132001
# 4  Female       21-30 years     Bangalore     530068
#
#   How Long You are Shopping Online ?  \
# 0                      Above 4 years
# 1                      Above 4 years
# 2                          3-4 years
# 3                          3-4 years
# 4                          2-3 years
#
#   How many times you have made an online purchase in the past 1 year?  \
# 0                                        31-40 times
# 1                                 41 times and above
# 2                                 41 times and above
# 3                                 Less than 10 times
# 4                                        11-20 times
#
#   How do you access the internet while shopping on-line?  \
# ...

# %%
df=df.drop(["Pin Code"],axis=1)

# %%
df["How do you access the internet while shopping on-line?"].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: How do you access the internet while shopping on-line?, dtype: int64

# %%
for i in df.columns[:-1]:
    total = len(df)*1.
    plt.figure(figsize=(12,6))
    plt.title("For feature '%s'"%i)
    ax=sns.countplot(df[i],hue=df['Gender'])
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width()
        y = p.get_height()
        ax.annotate(percentage, (x, y),ha='center')

# %% [raw]
#    Customer retention refers to the ability of a company or product to retain its customers over some specified period. High customer retention means customers of the product or business tend to return to, continue to buy or in some other way not defect to another product or business, or to non-use entirely. Selling organizations generally attempt to reduce customer defections. Customer retention starts with the first contact an organization has with a customer and continues throughout the entire lifetime of a relationship and successful retention efforts take this entire lifecycle into account. A company's ability to attract and retain new customers is related not only to its product or services, but also to the way it services its existing customers, the value the customers perceive as a result of utilizing the solutions, and the reputation it creates within and across the marketplace.
#        In this project, all the analysis and visualization are graded according to gender columns. So that we can get what and
# how much percentage of male and female contributions are there in online shopping.
#
# Following are some interpretation:
#     a- The graph clearly shows that females are more shopaholic.
#     b- The age group between 21 to 40 years are more shopaholic. 21.9% of the female of 21-30 age group is more active whereas          11.2% of the male from the age group 31-40 year are active.
#     c- Among other cities, Delhi contributes the highest male customer with 14.9%.  Most of the female customers are from              Greater Noida with 15.6% and also is the most shopping city.
#     d- More than 35% of the customers who were shopping online for more than 4 years.
#     e- Only 17.5% of the customer are shopping more than 41 times a year. 42.2% of customers only shop less than 10 times a            year.
#     f- Most of the customers are using mobile internet and smartphone. The maximum is windows/window mobile followed by                android.
#     g- Google chrome is most widely used by customers.
#     h- Customer who is exploring the website for more than 15min is likely to purchase.
#     i- Debit cards are the more preferred way of payment method.
#
# Some of the important factor which is strongly agreed from the customer point of view which should be followed by the company after the analysis are as followed:
#     -They need easy and understanding content on the shopping app/website.
#     -Similar product information.
#     -Complete information on sellers and products.
#     -Easy navigation on the website/app.
#     -Best loading and processing speed.
#     -Convenient payment method.
#     -Privacy of customer data.
#     -Responsive availability of several communication channels.
#     -Discount and monetary benefit.
#     -Return and replacement
